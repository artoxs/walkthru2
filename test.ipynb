# %%
import torch

# %%
torch.tensor(1)
# Out:
# tensor(1)

# %%
import numpy as np

# %%
a = arcsin(1)

# %%
a/pi/2
# Out:
# np.float64(0.25)

# %%
np.sin(200*pi)
# Out:
# np.float64(3.928773447456944e-15)

# %%
np.arcsin(0.8414709848078965)
# Out:
# np.float64(1.0)

# %%
pwd
# Out:
# '/home/axs'

# %%
# !pwd
# Out:
# /home/axs
